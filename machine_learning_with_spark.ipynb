# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, avg, col, concat, desc, explode, lit, min, max, split
from pyspark.sql.types import IntegerType

from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.regression import LinearRegression
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import CountVectorizer, IDF, Normalizer, PCA, RegexTokenizer, StandardScaler, StopWordsRemover, VectorAssembler, StringIndexer, MinMaxScaler, PCA
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

import re

# %%
data_dir = 'C:/Users/John/PycharmProjects/customer-attrition/data/'

# %%
spark = SparkSession.builder.appName("spark machine learning").getOrCreate()

# %%
df = spark.read.json(data_dir + 'Train_onetag_small.json')
df.persist()
# Out:
# DataFrame[Body: string, Id: bigint, Tags: string, Title: string, oneTag: string]

# %%
df.head()
# Out:
# Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php')

# %%
regexTokenizer = RegexTokenizer(inputCol='Body', outputCol='words', pattern="\\W")
df = regexTokenizer.transform(df)
df.head()
# Out:
# Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'])

# %%
body_length = udf(lambda x: len(x), IntegerType())
df = df.withColumn('BodyLength', body_length('words'))

# %%
df.head()
# Out:
# Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'], BodyLength=83)

# %%
number_of_paragraphs = udf(lambda x: len(re.findall('</p>',x)), IntegerType())
number_of_links = udf(lambda x: len(re.findall('</a>',x)), IntegerType())

# %%
df = df.withColumn('NumParagraphs', number_of_paragraphs('Body'))
df = df.withColumn('NumLinks', number_of_links('Body'))

# %%
df.head()
# Out:
# Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'], BodyLength=83, NumParagraphs=2, NumLinks=0)

# %%
assembler = VectorAssembler(inputCols = ['BodyLength', 'NumParagraphs', 'NumLinks'], outputCol = "NumFeatures")
df = assembler.transform(df)

# %%
df.head()
# Out:
# Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'], BodyLength=83, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([83.0, 2.0, 0.0]))

# %%
scaler = Normalizer(inputCol = 'NumFeatures', outputCol ='ScaledNumFeatures' )
df = scaler.transform(df)

# %%
df.head(2)
# Out:
# [Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'], BodyLength=83, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([83.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9997, 0.0241, 0.0])),
#  Row(Body='<p>In my favorite editor (vim), I regularly use ctrl-w to execute a certain action. Now, it quite often happens to me that firefox is the active window (on windows) while I still look at vim (thinking vim is the active window) and press ctrl-w which closes firefox. This is not what I want. Is there a way to stop ctrl-w from closing firefox?</p>\n\n<p>Rene</p>\n', Id=2, Tags='firefox', Title='How can I prevent firefox from closing when I press ctrl-w', oneTag='firefox', words=['p', 'in', 'my', 'favorite', 'editor', 'vim', 'i', 'regularly', 'use', 'ctrl', 'w', 'to', 'execute', 'a', 'certain', 'action', 'now', 'it', 'quite', 'often', 'happens', 'to', 'me', 'that', 'firefox', 'is', 'the', 'active', 'window', 'on', 'windows', 'while', 'i', 'still', 'look', 'at', 'vim', 'thinking', 'vim', 'is', 'the', 'active', 'window', 'and', 'press', 'ctrl', 'w', 'which', 'closes', 'firefox', 'this', 'is', 'not', 'what', 'i', 'want', 'is', 'there', 'a', 'way', 'to', 'stop', 'ctrl', 'w', 'from', 'closing', 'firefox', 'p', 'p', 'rene', 'p'], BodyLength=71, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([71.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9996, 0.0282, 0.0]))]

# %%
scaler2 = StandardScaler(inputCol = 'NumFeatures', outputCol ='ScaledNumFeatures2', withStd = True)
scalerModel = scaler2.fit(df)
df = scalerModel.transform(df)

# %%
df.head(2)
# Out:
# [Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'], BodyLength=83, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([83.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9997, 0.0241, 0.0]), ScaledNumFeatures2=DenseVector([0.4325, 0.7037, 0.0])),
#  Row(Body='<p>In my favorite editor (vim), I regularly use ctrl-w to execute a certain action. Now, it quite often happens to me that firefox is the active window (on windows) while I still look at vim (thinking vim is the active window) and press ctrl-w which closes firefox. This is not what I want. Is there a way to stop ctrl-w from closing firefox?</p>\n\n<p>Rene</p>\n', Id=2, Tags='firefox', Title='How can I prevent firefox from closing when I press ctrl-w', oneTag='firefox', words=['p', 'in', 'my', 'favorite', 'editor', 'vim', 'i', 'regularly', 'use', 'ctrl', 'w', 'to', 'execute', 'a', 'certain', 'action', 'now', 'it', 'quite', 'often', 'happens', 'to', 'me', 'that', 'firefox', 'is', 'the', 'active', 'window', 'on', 'windows', 'while', 'i', 'still', 'look', 'at', 'vim', 'thinking', 'vim', 'is', 'the', 'active', 'window', 'and', 'press', 'ctrl', 'w', 'which', 'closes', 'firefox', 'this', 'is', 'not', 'what', 'i', 'want', 'is', 'there', 'a', 'way', 'to', 'stop', 'ctrl', 'w', 'from', 'closing', 'firefox', 'p', 'p', 'rene', 'p'], BodyLength=71, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([71.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9996, 0.0282, 0.0]), ScaledNumFeatures2=DenseVector([0.3699, 0.7037, 0.0]))]

# %% [markdown]
# # Text Preprocessing

# %%
cv = CountVectorizer(inputCol='words', outputCol='TF', vocabSize = 1000)
cvmodel = cv.fit(df)
df = cvmodel.transform(df)
df.take(2)
# Out:
# [Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'], BodyLength=83, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([83.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9997, 0.0241, 0.0]), ScaledNumFeatures2=DenseVector([0.4325, 0.7037, 0.0]), TF=SparseVector(1000, {0: 4.0, 1: 6.0, 2: 2.0, 3: 3.0, 5: 2.0, 8: 4.0, 9: 1.0, 15: 1.0, 21: 2.0, 28: 1.0, 31: 1.0, 35: 3.0, 36: 1.0, 43: 2.0, 45: 2.0, 48: 1.0, 51: 1.0, 57: 6.0, 61: 2.0, 71: 1.0, 78: 1.0, 84: 3.0, 86: 1.0, 94: 1.0, 97: 1.0, 99: 1.0, 100: 1.0, 115: 1.0, 147: 2.0, 152: 1.0, 169: 1.0, 241: 1.0, 283: 1.0, 306: 1.0, 350: 2.0, 490: 1.0, 578: 1.0, 759: 1.0, 832: 2.0})),
#  Row(Body='<p>In my favorite editor (vim), I regularly use ctrl-w to execute a certain action. Now, it quite often happens to me that firefox is the active window (on windows) while I still look at vim (thinking vim is the active window) and press ctrl-w which closes firefox. This is not what I want. Is there a way to stop ctrl-w from closing firefox?</p>\n\n<p>Rene</p>\n', Id=2, Tags='firefox', Title='How can I prevent firefox from closing when I press ctrl-w', oneTag='firefox', words=['p', 'in', 'my', 'favorite', 'editor', 'vim', 'i', 'regularly', 'use', 'ctrl', 'w', 'to', 'execute', 'a', 'certain', 'action', 'now', 'it', 'quite', 'often', 'happens', 'to', 'me', 'that', 'firefox', 'is', 'the', 'active', 'window', 'on', 'windows', 'while', 'i', 'still', 'look', 'at', 'vim', 'thinking', 'vim', 'is', 'the', 'active', 'window', 'and', 'press', 'ctrl', 'w', 'which', 'closes', 'firefox', 'this', 'is', 'not', 'what', 'i', 'want', 'is', 'there', 'a', 'way', 'to', 'stop', 'ctrl', 'w', 'from', 'closing', 'firefox', 'p', 'p', 'rene', 'p'], BodyLength=71, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([71.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9996, 0.0282, 0.0]), ScaledNumFeatures2=DenseVector([0.3699, 0.7037, 0.0]), TF=SparseVector(1000, {0: 4.0, 1: 2.0, 2: 3.0, 3: 3.0, 5: 2.0, 8: 4.0, 9: 1.0, 11: 1.0, 12: 1.0, 14: 1.0, 15: 1.0, 20: 1.0, 22: 1.0, 26: 1.0, 31: 1.0, 44: 1.0, 51: 1.0, 55: 1.0, 61: 1.0, 62: 1.0, 65: 1.0, 82: 1.0, 86: 1.0, 136: 1.0, 177: 1.0, 226: 1.0, 297: 1.0, 320: 2.0, 345: 1.0, 489: 1.0, 528: 3.0, 572: 1.0, 747: 1.0, 794: 1.0, 861: 1.0, 895: 1.0, 913: 2.0, 934: 3.0, 978: 1.0}))]

# %%
cvmodel.vocabulary
# Out:
# ['p',
#  'the',
#  'i',
#  'to',
#  'code',
#  'a',
#  'gt',
#  'lt',
#  'is',
#  'and',
#  'pre',
#  'in',
#  'this',
#  'of',
#  'it',
#  'that',
#  'for',
#  '0',
#  '1',
#  'have',
#  'my',
#  'if',
#  'on',
#  'but',
#  'with',
#  'can',
#  'not',
#  'be',
#  'as',
#  't',
#  'li',
#  'from',
#  '2',
#  's',
#  'http',
#  'an',
#  'm',
#  'strong',
#  'new',
#  'how',
#  'do',
#  'com',
#  'so',
#  'or',
#  'at',
#  'using',
#  'when',
#  'am',
#  'like',
#  'class',
#  'id',
#  'there',
#  'get',
#  'are',
#  'name',
#  'what',
#  'any',
#  'file',
#  'string',
#  'data',
#  'all',
#  'which',
#  'want',
#  'would',
#  'amp',
#  'use',
#  'java',
#  'function',
#  'public',
#  'some',
#  '3',
#  'text',
#  'error',
#  'android',
#  'value',
#  'c',
#  'x',
#  'href',
#  'you',
#  'one',
#  'by',
#  'user',
#  'me',
#  'server',
#  'type',
#  'here',
#  'way',
#  'return',
#  'int',
#  'will',
#  'div',
#  'need',
#  'then',
#  'set',
#  'e',
#  'system',
#  'has',
#  'problem',
#  'out',
#  'php',
#  'no',
#  'just',
#  '4',
#  'org',
#  'know',
#  'html',
#  'only',
#  'where',
#  'page',
#  'application',
#  '5',
#  'thanks',
#  'var',
#  'br',
#  'we',
#  'd',
#  'should',
#  'does',
#  'add',
#  'n',
#  'true',
#  've',
#  'void',
#  'em',
#  'was',
#  'rel',
#  'work',
#  'time',
#  'other',
#  '10',
#  'app',
#  'null',
#  'method',
#  'b',
#  'table',
#  'list',
#  'now',
#  'into',
#  'help',
#  'end',
#  'trying',
#  'following',
#  'object',
#  'view',
#  'nofollow',
#  'up',
#  'example',
#  'image',
#  'same',
#  'create',
#  'also',
#  'each',
#  'something',
#  'www',
#  'web',
#  'first',
#  'array',
#  'line',
#  'script',
#  'find',
#  'don',
#  'run',
#  'could',
#  'select',
#  'about',
#  'test',
#  'make',
#  'form',
#  'r',
#  'files',
#  'tried',
#  'ul',
#  'net',
#  'url',
#  'td',
#  'self',
#  'input',
#  'windows',
#  'button',
#  'see',
#  'blockquote',
#  'database',
#  'question',
#  'content',
#  'else',
#  'more',
#  'works',
#  'xml',
#  '6',
#  '00',
#  'two',
#  '8',
#  'after',
#  'they',
#  'possible',
#  'false',
#  'right',
#  'them',
#  'y',
#  'working',
#  '7',
#  'width',
#  'main',
#  'src',
#  'try',
#  'private',
#  'however',
#  'version',
#  'number',
#  'f',
#  'result',
#  'these',
#  'because',
#  'project',
#  'key',
#  'message',
#  'why',
#  'doesn',
#  'used',
#  'please',
#  'query',
#  'import',
#  'size',
#  'item',
#  'call',
#  'show',
#  'while',
#  'title',
#  'found',
#  'been',
#  'anyone',
#  'change',
#  'post',
#  'document',
#  'users',
#  'different',
#  'its',
#  'start',
#  'able',
#  'log',
#  'access',
#  'another',
#  'event',
#  'case',
#  'request',
#  'values',
#  'update',
#  'client',
#  'edit',
#  'index',
#  '9',
#  'service',
#  'read',
#  'without',
#  'source',
#  'javascript',
#  'left',
#  'style',
#  'open',
#  'jquery',
#  'img',
#  'running',
#  'row',
#  'h',
#  'display',
#  'fine',
#  'write',
#  'site',
#  'google',
#  'seems',
#  'height',
#  'click',
#  'date',
#  '12',
#  'static',
#  'etc',
#  'option',
#  'path',
#  'output',
#  'property',
#  '20',
#  'doing',
#  'model',
#  'g',
#  'default',
#  'link',
#  'than',
#  'through',
#  'echo',
#  'below',
#  'include',
#  'even',
#  'solution',
#  'lib',
#  '11',
#  'sql',
#  'questions',
#  'still',
#  'program',
#  'such',
#  'library',
#  'getting',
#  'exception',
#  'created',
#  'simple',
#  'context',
#  'png',
#  'your',
#  'very',
#  'before',
#  'apache',
#  'both',
#  'ol',
#  'sure',
#  '100',
#  'order',
#  'asp',
#  'command',
#  'field',
#  'color',
#  'window',
#  'images',
#  'column',
#  'load',
#  'having',
#  'thread',
#  'background',
#  'think',
#  'js',
#  'wrong',
#  'go',
#  'point',
#  'element',
#  'process',
#  'length',
#  'really',
#  'tr',
#  'span',
#  'being',
#  'every',
#  'back',
#  'current',
#  'called',
#  'css',
#  'label',
#  'action',
#  'issue',
#  'many',
#  'info',
#  'stack',
#  'check',
#  'got',
#  'top',
#  'since',
#  'connection',
#  'looking',
#  'put',
#  'second',
#  'search',
#  'db',
#  'local',
#  'over',
#  'email',
#  'above',
#  'password',
#  'done',
#  'api',
#  'response',
#  'between',
#  'build',
#  'cannot',
#  'alt',
#  'print',
#  'j',
#  'well',
#  'body',
#  'directory',
#  'count',
#  'description',
#  'location',
#  'information',
#  'next',
#  'address',
#  'root',
#  'good',
#  '01',
#  'let',
#  'control',
#  'o',
#  'microsoft',
#  'part',
#  'map',
#  'advance',
#  'our',
#  'instead',
#  'v',
#  'much',
#  'their',
#  'best',
#  'position',
#  '2012',
#  'idea',
#  'custom',
#  'format',
#  'mysql',
#  'already',
#  'say',
#  'long',
#  'instance',
#  'variable',
#  'send',
#  '13',
#  '16',
#  'may',
#  'currently',
#  'results',
#  'inside',
#  '15',
#  'k',
#  'header',
#  'enter',
#  'items',
#  'correct',
#  'home',
#  'controller',
#  'domain',
#  'node',
#  'z',
#  'override',
#  'based',
#  '30',
#  'seem',
#  'group',
#  'options',
#  'last',
#  'ui',
#  'added',
#  'screen',
#  'someone',
#  'folder',
#  'save',
#  'session',
#  'website',
#  'close',
#  'stackoverflow',
#  'better',
#  'username',
#  'python',
#  'bit',
#  'json',
#  'menu',
#  'box',
#  'login',
#  'console',
#  'via',
#  'l',
#  'usr',
#  'looks',
#  'anything',
#  'def',
#  'none',
#  'https',
#  'char',
#  'lang',
#  'within',
#  'multiple',
#  'activity',
#  'everything',
#  'appreciated',
#  'tag',
#  'insert',
#  'ajax',
#  'config',
#  'had',
#  'again',
#  'understand',
#  'parent',
#  'final',
#  'install',
#  'catch',
#  'browser',
#  'objects',
#  'store',
#  'os',
#  'ideas',
#  'double',
#  'contains',
#  'thing',
#  'given',
#  'look',
#  'jpg',
#  'template',
#  'font',
#  'reference',
#  'those',
#  'answer',
#  'going',
#  'connect',
#  'debug',
#  'imgur',
#  'frame',
#  'rows',
#  'down',
#  'ruby',
#  'foo',
#  'around',
#  'always',
#  'too',
#  'state',
#  'remove',
#  'block',
#  'status',
#  'intent',
#  'yes',
#  'must',
#  'errors',
#  'thank',
#  '08',
#  'layout',
#  'en',
#  'did',
#  'far',
#  'u',
#  'core',
#  'memory',
#  'most',
#  'installed',
#  'single',
#  'w',
#  'framework',
#  'bar',
#  'linux',
#  'machine',
#  'specific',
#  'loop',
#  'give',
#  '14',
#  'delete',
#  'begin',
#  'take',
#  'ip',
#  'lot',
#  'returns',
#  '02',
#  'facebook',
#  're',
#  'device',
#  'things',
#  'creating',
#  'base',
#  'ok',
#  'nothing',
#  'missing',
#  'module',
#  'fields',
#  'host',
#  'own',
#  'uses',
#  'support',
#  'androidruntime',
#  'might',
#  'similar',
#  'integer',
#  'float',
#  'actually',
#  'figure',
#  '50',
#  'configuration',
#  '2010',
#  'alert',
#  'tell',
#  'us',
#  'execute',
#  'std',
#  'tostring',
#  'few',
#  'empty',
#  'note',
#  'changes',
#  'xmlns',
#  'pass',
#  'failed',
#  'off',
#  'settings',
#  'network',
#  'either',
#  'package',
#  'interface',
#  '2011',
#  'eclipse',
#  'mode',
#  'plugin',
#  '25',
#  'elements',
#  'methods',
#  'classes',
#  'rb',
#  'head',
#  'shows',
#  'properties',
#  'video',
#  '18',
#  'const',
#  'port',
#  'pages',
#  'break',
#  'columns',
#  'made',
#  'bin',
#  'cell',
#  'functions',
#  '23',
#  'allow',
#  '21',
#  'generated',
#  'nbsp',
#  'q',
#  'submit',
#  'once',
#  'setup',
#  'product',
#  'grid',
#  '22',
#  'reason',
#  'copy',
#  'h2',
#  'times',
#  'aspx',
#  'sub',
#  'auto',
#  'target',
#  'available',
#  'dev',
#  '04',
#  'jar',
#  'keep',
#  'filter',
#  'required',
#  'side',
#  'convert',
#  'tables',
#  'handle',
#  'center',
#  'println',
#  'task',
#  'selected',
#  'join',
#  'setting',
#  'security',
#  'gets',
#  'category',
#  '17',
#  '05',
#  'lines',
#  'under',
#  'though',
#  'boolean',
#  'gems',
#  'localhost',
#  'entity',
#  'isn',
#  'space',
#  'admin',
#  'sun',
#  'fix',
#  'dll',
#  'implement',
#  'internal',
#  'wondering',
#  'nil',
#  'init',
#  'val',
#  '09',
#  'parameters',
#  '19',
#  'binding',
#  'rails',
#  'txt',
#  'maybe',
#  'level',
#  'super',
#  'several',
#  'child',
#  'defined',
#  'non',
#  '03',
#  'parameter',
#  'place',
#  '24',
#  'sort',
#  'needs',
#  'language',
#  'py',
#  'adding',
#  'dialog',
#  'cache',
#  'statement',
#  'section',
#  'kind',
#  'problems',
#  'total',
#  '27',
#  'margin',
#  'utf',
#  'filename',
#  'nsstring',
#  'writing',
#  'border',
#  'account',
#  'computer',
#  'changed',
#  'correctly',
#  'match',
#  '255',
#  'tab',
#  'bundle',
#  'define',
#  'didn',
#  'warning',
#  'basically',
#  'solve',
#  'release',
#  'protected',
#  'hr',
#  'structure',
#  'replace',
#  'frac',
#  'software',
#  'extends',
#  'foreach',
#  'thought',
#  '29',
#  'full',
#  'byte',
#  'word',
#  'stored',
#  'ie',
#  '_',
#  'day',
#  'sender',
#  'record',
#  'clear',
#  'never',
#  'services',
#  'were',
#  'pdf',
#  '32',
#  'stop',
#  '07',
#  'resources',
#  'models',
#  'springframework',
#  'move',
#  'alloc',
#  'people',
#  'started',
#  'checked',
#  'virtual',
#  'attribute',
#  'gives',
#  'suggestions',
#  'container',
#  'ubuntu',
#  'numbers',
#  'old',
#  'mail',
#  'sample',
#  'unknown',
#  'small',
#  'bool',
#  'align',
#  'collection',
#  'success',
#  'visual',
#  'person',
#  'compile',
#  'mean',
#  'standard',
#  'encoding',
#  'param',
#  'iphone',
#  'append',
#  'projects',
#  'events',
#  'bytes',
#  'str',
#  '06',
#  'rather',
#  'written',
#  'reading',
#  'resource',
#  'wrap_content',
#  'exists',
#  'details',
#  'certain',
#  'widget',
#  'handler',
#  'download',
#  'stuff',
#  'parse',
#  '40',
#  'until',
#  'documentation',
#  'expected',
#  'variables',
#  'socket',
#  'git',
#  'little',
#  'servlet',
#  'hello',
#  'th',
#  'modules',
#  'environment',
#  'generate',
#  'says',
#  'development',
#  'easy',
#  'simply',
#  'large',
#  'three',
#  '31',
#  'exe',
#  'game',
#  'approach',
#  'calls',
#  'args',
#  'normal',
#  'bottom',
#  'global',
#  'views',
#  'types',
#  'javax',
#  'upload',
#  'invoke',
#  'tags',
#  'hibernate',
#  'switch',
#  'stream',
#  'onclick',
#  'making',
#  'remote',
#  'layout_width',
#  'layout_height',
#  'entry',
#  'im',
#  'namespace',
#  'll',
#  'whole',
#  'he',
#  'great',
#  'original',
#  'textview',
#  'hidden',
#  'io',
#  'component',
#  'internet',
#  'free',
#  'comment',
#  'obj',
#  'links',
#  'phone',
#  'happens',
#  'loaded',
#  'developer',
#  'messages',
#  'testing',
#  'names',
#  'automatically',
#  'whether',
#  'studio',
#  'mvc',
#  '2008',
#  'come',
#  'play',
#  'course',
#  'points',
#  '200',
#  'chrome',
#  'xsl',
#  'appears',
#  'related',
#  'pattern',
#  'loading',
#  'pretty',
#  'who',
#  'provide',
#  'basic',
#  'django',
#  'require',
#  'range',
#  'per',
#  'player',
#  'means',
#  'particular',
#  'padding',
#  'quite',
#  'real',
#  'forms',
#  'tools',
#  'util',
#  'datetime',
#  'character',
#  'buffer',
#  'random',
#  '_post',
#  'vector',
#  'itself',
#  'ms',
#  'icon',
#  'valid',
#  'records',
#  'cursor',
#  'implementation',
#  'active',
#  'achieve',
#  'drive',
#  'yet',
#  'goes',
#  'runat',
#  'calling',
#  'max',
#  'unable',
#  'maps',
#  'bind',
#  'params',
#  'except',
#  'takes',
#  'displayed',
#  'hard',
#  'report',
#  'share',
#  'common',
#  'makes',
#  'issues',
#  'firefox',
#  'temp',
#  'runs',
#  'follows',
#  'seen',
#  'limit',
#  'properly',
#  '64',
#  'company',
#  'characters',
#  'doc',
#  'applications',
#  'step',
#  'tool',
#  'native',
#  'h1',
#  'attr',
#  'sent',
#  'exist',
#  'external',
#  'duplicate',
#  'controls',
#  'complete',
#  'sum',
#  'exactly',
#  'directly',
#  'schema',
#  'panel',
#  'min',
#  'posts',
#  'performance',
#  'job',
#  'difference',
#  'dim',
#  'matrix',
#  'seconds',
#  'separate',
#  'expression',
#  'docs',
#  'syntax',
#  'textbox',
#  'examples',
#  'article',
#  'book',
#  'thinking',
#  'render',
#  'flash',
#  'mac',
#  'checkbox',
#  'printf',
#  'runtime',
#  'canvas',
#  'existing',
#  'shared',
#  '28',
#  'servers',
#  'customer',
#  'desktop',
#  'buttons',
#  'previous',
#  'master',
#  'math',
#  '000',
#  'comes',
#  'blog',
#  'wordpress']

# %%
# seeing the least common words
cvmodel.vocabulary[::-1] # the list invertes
# Out:
# ['wordpress',
#  'blog',
#  'comes',
#  '000',
#  'math',
#  'master',
#  'previous',
#  'buttons',
#  'desktop',
#  'customer',
#  'servers',
#  '28',
#  'shared',
#  'existing',
#  'canvas',
#  'runtime',
#  'printf',
#  'checkbox',
#  'mac',
#  'flash',
#  'render',
#  'thinking',
#  'book',
#  'article',
#  'examples',
#  'textbox',
#  'syntax',
#  'docs',
#  'expression',
#  'separate',
#  'seconds',
#  'matrix',
#  'dim',
#  'difference',
#  'job',
#  'performance',
#  'posts',
#  'min',
#  'panel',
#  'schema',
#  'directly',
#  'exactly',
#  'sum',
#  'complete',
#  'controls',
#  'duplicate',
#  'external',
#  'exist',
#  'sent',
#  'attr',
#  'h1',
#  'native',
#  'tool',
#  'step',
#  'applications',
#  'doc',
#  'characters',
#  'company',
#  '64',
#  'properly',
#  'limit',
#  'seen',
#  'follows',
#  'runs',
#  'temp',
#  'firefox',
#  'issues',
#  'makes',
#  'common',
#  'share',
#  'report',
#  'hard',
#  'displayed',
#  'takes',
#  'except',
#  'params',
#  'bind',
#  'maps',
#  'unable',
#  'max',
#  'calling',
#  'runat',
#  'goes',
#  'yet',
#  'drive',
#  'achieve',
#  'active',
#  'implementation',
#  'cursor',
#  'records',
#  'valid',
#  'icon',
#  'ms',
#  'itself',
#  'vector',
#  '_post',
#  'random',
#  'buffer',
#  'character',
#  'datetime',
#  'util',
#  'tools',
#  'forms',
#  'real',
#  'quite',
#  'padding',
#  'particular',
#  'means',
#  'player',
#  'per',
#  'range',
#  'require',
#  'django',
#  'basic',
#  'provide',
#  'who',
#  'pretty',
#  'loading',
#  'pattern',
#  'related',
#  'appears',
#  'xsl',
#  'chrome',
#  '200',
#  'points',
#  'course',
#  'play',
#  'come',
#  '2008',
#  'mvc',
#  'studio',
#  'whether',
#  'automatically',
#  'names',
#  'testing',
#  'messages',
#  'developer',
#  'loaded',
#  'happens',
#  'phone',
#  'links',
#  'obj',
#  'comment',
#  'free',
#  'internet',
#  'component',
#  'io',
#  'hidden',
#  'textview',
#  'original',
#  'great',
#  'he',
#  'whole',
#  'll',
#  'namespace',
#  'im',
#  'entry',
#  'layout_height',
#  'layout_width',
#  'remote',
#  'making',
#  'onclick',
#  'stream',
#  'switch',
#  'hibernate',
#  'tags',
#  'invoke',
#  'upload',
#  'javax',
#  'types',
#  'views',
#  'global',
#  'bottom',
#  'normal',
#  'args',
#  'calls',
#  'approach',
#  'game',
#  'exe',
#  '31',
#  'three',
#  'large',
#  'simply',
#  'easy',
#  'development',
#  'says',
#  'generate',
#  'environment',
#  'modules',
#  'th',
#  'hello',
#  'servlet',
#  'little',
#  'git',
#  'socket',
#  'variables',
#  'expected',
#  'documentation',
#  'until',
#  '40',
#  'parse',
#  'stuff',
#  'download',
#  'handler',
#  'widget',
#  'certain',
#  'details',
#  'exists',
#  'wrap_content',
#  'resource',
#  'reading',
#  'written',
#  'rather',
#  '06',
#  'str',
#  'bytes',
#  'events',
#  'projects',
#  'append',
#  'iphone',
#  'param',
#  'encoding',
#  'standard',
#  'mean',
#  'compile',
#  'person',
#  'visual',
#  'success',
#  'collection',
#  'align',
#  'bool',
#  'small',
#  'unknown',
#  'sample',
#  'mail',
#  'old',
#  'numbers',
#  'ubuntu',
#  'container',
#  'suggestions',
#  'gives',
#  'attribute',
#  'virtual',
#  'checked',
#  'started',
#  'people',
#  'alloc',
#  'move',
#  'springframework',
#  'models',
#  'resources',
#  '07',
#  'stop',
#  '32',
#  'pdf',
#  'were',
#  'services',
#  'never',
#  'clear',
#  'record',
#  'sender',
#  'day',
#  '_',
#  'ie',
#  'stored',
#  'word',
#  'byte',
#  'full',
#  '29',
#  'thought',
#  'foreach',
#  'extends',
#  'software',
#  'frac',
#  'replace',
#  'structure',
#  'hr',
#  'protected',
#  'release',
#  'solve',
#  'basically',
#  'warning',
#  'didn',
#  'define',
#  'bundle',
#  'tab',
#  '255',
#  'match',
#  'correctly',
#  'changed',
#  'computer',
#  'account',
#  'border',
#  'writing',
#  'nsstring',
#  'filename',
#  'utf',
#  'margin',
#  '27',
#  'total',
#  'problems',
#  'kind',
#  'section',
#  'statement',
#  'cache',
#  'dialog',
#  'adding',
#  'py',
#  'language',
#  'needs',
#  'sort',
#  '24',
#  'place',
#  'parameter',
#  '03',
#  'non',
#  'defined',
#  'child',
#  'several',
#  'super',
#  'level',
#  'maybe',
#  'txt',
#  'rails',
#  'binding',
#  '19',
#  'parameters',
#  '09',
#  'val',
#  'init',
#  'nil',
#  'wondering',
#  'internal',
#  'implement',
#  'dll',
#  'fix',
#  'sun',
#  'admin',
#  'space',
#  'isn',
#  'entity',
#  'localhost',
#  'gems',
#  'boolean',
#  'though',
#  'under',
#  'lines',
#  '05',
#  '17',
#  'category',
#  'gets',
#  'security',
#  'setting',
#  'join',
#  'selected',
#  'task',
#  'println',
#  'center',
#  'handle',
#  'tables',
#  'convert',
#  'side',
#  'required',
#  'filter',
#  'keep',
#  'jar',
#  '04',
#  'dev',
#  'available',
#  'target',
#  'auto',
#  'sub',
#  'aspx',
#  'times',
#  'h2',
#  'copy',
#  'reason',
#  '22',
#  'grid',
#  'product',
#  'setup',
#  'once',
#  'submit',
#  'q',
#  'nbsp',
#  'generated',
#  '21',
#  'allow',
#  '23',
#  'functions',
#  'cell',
#  'bin',
#  'made',
#  'columns',
#  'break',
#  'pages',
#  'port',
#  'const',
#  '18',
#  'video',
#  'properties',
#  'shows',
#  'head',
#  'rb',
#  'classes',
#  'methods',
#  'elements',
#  '25',
#  'plugin',
#  'mode',
#  'eclipse',
#  '2011',
#  'interface',
#  'package',
#  'either',
#  'network',
#  'settings',
#  'off',
#  'failed',
#  'pass',
#  'xmlns',
#  'changes',
#  'note',
#  'empty',
#  'few',
#  'tostring',
#  'std',
#  'execute',
#  'us',
#  'tell',
#  'alert',
#  '2010',
#  'configuration',
#  '50',
#  'figure',
#  'actually',
#  'float',
#  'integer',
#  'similar',
#  'might',
#  'androidruntime',
#  'support',
#  'uses',
#  'own',
#  'host',
#  'fields',
#  'module',
#  'missing',
#  'nothing',
#  'ok',
#  'base',
#  'creating',
#  'things',
#  'device',
#  're',
#  'facebook',
#  '02',
#  'returns',
#  'lot',
#  'ip',
#  'take',
#  'begin',
#  'delete',
#  '14',
#  'give',
#  'loop',
#  'specific',
#  'machine',
#  'linux',
#  'bar',
#  'framework',
#  'w',
#  'single',
#  'installed',
#  'most',
#  'memory',
#  'core',
#  'u',
#  'far',
#  'did',
#  'en',
#  'layout',
#  '08',
#  'thank',
#  'errors',
#  'must',
#  'yes',
#  'intent',
#  'status',
#  'block',
#  'remove',
#  'state',
#  'too',
#  'always',
#  'around',
#  'foo',
#  'ruby',
#  'down',
#  'rows',
#  'frame',
#  'imgur',
#  'debug',
#  'connect',
#  'going',
#  'answer',
#  'those',
#  'reference',
#  'font',
#  'template',
#  'jpg',
#  'look',
#  'given',
#  'thing',
#  'contains',
#  'double',
#  'ideas',
#  'os',
#  'store',
#  'objects',
#  'browser',
#  'catch',
#  'install',
#  'final',
#  'parent',
#  'understand',
#  'again',
#  'had',
#  'config',
#  'ajax',
#  'insert',
#  'tag',
#  'appreciated',
#  'everything',
#  'activity',
#  'multiple',
#  'within',
#  'lang',
#  'char',
#  'https',
#  'none',
#  'def',
#  'anything',
#  'looks',
#  'usr',
#  'l',
#  'via',
#  'console',
#  'login',
#  'box',
#  'menu',
#  'json',
#  'bit',
#  'python',
#  'username',
#  'better',
#  'stackoverflow',
#  'close',
#  'website',
#  'session',
#  'save',
#  'folder',
#  'someone',
#  'screen',
#  'added',
#  'ui',
#  'last',
#  'options',
#  'group',
#  'seem',
#  '30',
#  'based',
#  'override',
#  'z',
#  'node',
#  'domain',
#  'controller',
#  'home',
#  'correct',
#  'items',
#  'enter',
#  'header',
#  'k',
#  '15',
#  'inside',
#  'results',
#  'currently',
#  'may',
#  '16',
#  '13',
#  'send',
#  'variable',
#  'instance',
#  'long',
#  'say',
#  'already',
#  'mysql',
#  'format',
#  'custom',
#  'idea',
#  '2012',
#  'position',
#  'best',
#  'their',
#  'much',
#  'v',
#  'instead',
#  'our',
#  'advance',
#  'map',
#  'part',
#  'microsoft',
#  'o',
#  'control',
#  'let',
#  '01',
#  'good',
#  'root',
#  'address',
#  'next',
#  'information',
#  'location',
#  'description',
#  'count',
#  'directory',
#  'body',
#  'well',
#  'j',
#  'print',
#  'alt',
#  'cannot',
#  'build',
#  'between',
#  'response',
#  'api',
#  'done',
#  'password',
#  'above',
#  'email',
#  'over',
#  'local',
#  'db',
#  'search',
#  'second',
#  'put',
#  'looking',
#  'connection',
#  'since',
#  'top',
#  'got',
#  'check',
#  'stack',
#  'info',
#  'many',
#  'issue',
#  'action',
#  'label',
#  'css',
#  'called',
#  'current',
#  'back',
#  'every',
#  'being',
#  'span',
#  'tr',
#  'really',
#  'length',
#  'process',
#  'element',
#  'point',
#  'go',
#  'wrong',
#  'js',
#  'think',
#  'background',
#  'thread',
#  'having',
#  'load',
#  'column',
#  'images',
#  'window',
#  'color',
#  'field',
#  'command',
#  'asp',
#  'order',
#  '100',
#  'sure',
#  'ol',
#  'both',
#  'apache',
#  'before',
#  'very',
#  'your',
#  'png',
#  'context',
#  'simple',
#  'created',
#  'exception',
#  'getting',
#  'library',
#  'such',
#  'program',
#  'still',
#  'questions',
#  'sql',
#  '11',
#  'lib',
#  'solution',
#  'even',
#  'include',
#  'below',
#  'echo',
#  'through',
#  'than',
#  'link',
#  'default',
#  'g',
#  'model',
#  'doing',
#  '20',
#  'property',
#  'output',
#  'path',
#  'option',
#  'etc',
#  'static',
#  '12',
#  'date',
#  'click',
#  'height',
#  'seems',
#  'google',
#  'site',
#  'write',
#  'fine',
#  'display',
#  'h',
#  'row',
#  'running',
#  'img',
#  'jquery',
#  'open',
#  'style',
#  'left',
#  'javascript',
#  'source',
#  'without',
#  'read',
#  'service',
#  '9',
#  'index',
#  'edit',
#  'client',
#  'update',
#  'values',
#  'request',
#  'case',
#  'event',
#  'another',
#  'access',
#  'log',
#  'able',
#  'start',
#  'its',
#  'different',
#  'users',
#  'document',
#  'post',
#  'change',
#  'anyone',
#  'been',
#  'found',
#  'title',
#  'while',
#  'show',
#  'call',
#  'item',
#  'size',
#  'import',
#  'query',
#  'please',
#  'used',
#  'doesn',
#  'why',
#  'message',
#  'key',
#  'project',
#  'because',
#  'these',
#  'result',
#  'f',
#  'number',
#  'version',
#  'however',
#  'private',
#  'try',
#  'src',
#  'main',
#  'width',
#  '7',
#  'working',
#  'y',
#  'them',
#  'right',
#  'false',
#  'possible',
#  'they',
#  'after',
#  '8',
#  'two',
#  '00',
#  '6',
#  'xml',
#  'works',
#  'more',
#  'else',
#  'content',
#  'question',
#  'database',
#  'blockquote',
#  'see',
#  'button',
#  'windows',
#  'input',
#  'self',
#  'td',
#  'url',
#  'net',
#  'ul',
#  'tried',
#  'files',
#  'r',
#  'form',
#  'make',
#  'test',
#  'about',
#  'select',
#  'could',
#  'run',
#  'don',
#  'find',
#  'script',
#  'line',
#  'array',
#  'first',
#  'web',
#  'www',
#  'something',
#  'each',
#  'also',
#  'create',
#  'same',
#  'image',
#  'example',
#  'up',
#  'nofollow',
#  'view',
#  'object',
#  'following',
#  'trying',
#  'end',
#  'help',
#  'into',
#  'now',
#  'list',
#  'table',
#  'b',
#  'method',
#  'null',
#  'app',
#  '10',
#  'other',
#  'time',
#  'work',
#  'rel',
#  'was',
#  'em',
#  'void',
#  've',
#  'true',
#  'n',
#  'add',
#  'does',
#  'should',
#  'd',
#  'we',
#  'br',
#  'var',
#  'thanks',
#  '5',
#  'application',
#  'page',
#  'where',
#  'only',
#  'html',
#  'know',
#  'org',
#  '4',
#  'just',
#  'no',
#  'php',
#  'out',
#  'problem',
#  'has',
#  'system',
#  'e',
#  'set',
#  'then',
#  'need',
#  'div',
#  'will',
#  'int',
#  'return',
#  'way',
#  'here',
#  'type',
#  'server',
#  'me',
#  'user',
#  'by',
#  'one',
#  'you',
#  'href',
#  'x',
#  'c',
#  'value',
#  'android',
#  'error',
#  'text',
#  '3',
#  'some',
#  'public',
#  'function',
#  'java',
#  'use',
#  'amp',
#  'would',
#  'want',
#  'which',
#  'all',
#  'data',
#  'string',
#  'file',
#  'any',
#  'what',
#  'name',
#  'are',
#  'get',
#  'there',
#  'id',
#  'class',
#  'like',
#  'am',
#  'when',
#  'using',
#  'at',
#  'or',
#  'so',
#  'com',
#  'do',
#  'how',
#  'new',
#  'strong',
#  'm',
#  'an',
#  'http',
#  's',
#  '2',
#  'from',
#  'li',
#  't',
#  'as',
#  'be',
#  'not',
#  'can',
#  'with',
#  'but',
#  'on',
#  'if',
#  'my',
#  'have',
#  '1',
#  '0',
#  'for',
#  'that',
#  'it',
#  'of',
#  'this',
#  'in',
#  'pre',
#  'and',
#  'is',
#  'lt',
#  'gt',
#  'a',
#  'code',
#  'to',
#  'i',
#  'the',
#  'p']

# %%
cvmodel.vocabulary[-10:]
# Out:
# ['customer',
#  'desktop',
#  'buttons',
#  'previous',
#  'master',
#  'math',
#  '000',
#  'comes',
#  'blog',
#  'wordpress']

# %%
idf = IDF(inputCol = 'TF', outputCol = 'TFIDF')
idfmodel = idf.fit(df)
df = idfmodel.transform(df)
df.head()
# Out:
# Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'], BodyLength=83, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([83.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9997, 0.0241, 0.0]), ScaledNumFeatures2=DenseVector([0.4325, 0.7037, 0.0]), TF=SparseVector(1000, {0: 4.0, 1: 6.0, 2: 2.0, 3: 3.0, 5: 2.0, 8: 4.0, 9: 1.0, 15: 1.0, 21: 2.0, 28: 1.0, 31: 1.0, 35: 3.0, 36: 1.0, 43: 2.0, 45: 2.0, 48: 1.0, 51: 1.0, 57: 6.0, 61: 2.0, 71: 1.0, 78: 1.0, 84: 3.0, 86: 1.0, 94: 1.0, 97: 1.0, 99: 1.0, 100: 1.0, 115: 1.0, 147: 2.0, 152: 1.0, 169: 1.0, 241: 1.0, 283: 1.0, 306: 1.0, 350: 2.0, 490: 1.0, 578: 1.0, 759: 1.0, 832: 2.0}), TFIDF=SparseVector(1000, {0: 0.0026, 1: 0.7515, 2: 0.1374, 3: 0.3184, 5: 0.3823, 8: 1.0754, 9: 0.3344, 15: 0.5899, 21: 1.8551, 28: 1.1263, 31: 1.1113, 35: 3.3134, 36: 1.2545, 43: 2.3741, 45: 2.3753, 48: 1.2254, 51: 1.1879, 57: 11.0264, 61: 2.8957, 71: 2.1945, 78: 1.6947, 84: 6.5898, 86: 1.6136, 94: 2.3569, 97: 1.8218, 99: 2.6292, 100: 1.9206, 115: 2.3592, 147: 5.4841, 152: 2.1116, 169: 2.6328, 241: 2.5745, 283: 3.2325, 306: 3.2668, 350: 6.2367, 490: 3.8893, 578: 3.6182, 759: 3.7771, 832: 8.8964}))

# %%
indexer = StringIndexer(inputCol = 'oneTag', outputCol = 'label')
df = indexer.fit(df).transform(df)

# %%
df.head()
# Out:
# Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'], BodyLength=83, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([83.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9997, 0.0241, 0.0]), ScaledNumFeatures2=DenseVector([0.4325, 0.7037, 0.0]), TF=SparseVector(1000, {0: 4.0, 1: 6.0, 2: 2.0, 3: 3.0, 5: 2.0, 8: 4.0, 9: 1.0, 15: 1.0, 21: 2.0, 28: 1.0, 31: 1.0, 35: 3.0, 36: 1.0, 43: 2.0, 45: 2.0, 48: 1.0, 51: 1.0, 57: 6.0, 61: 2.0, 71: 1.0, 78: 1.0, 84: 3.0, 86: 1.0, 94: 1.0, 97: 1.0, 99: 1.0, 100: 1.0, 115: 1.0, 147: 2.0, 152: 1.0, 169: 1.0, 241: 1.0, 283: 1.0, 306: 1.0, 350: 2.0, 490: 1.0, 578: 1.0, 759: 1.0, 832: 2.0}), TFIDF=SparseVector(1000, {0: 0.0026, 1: 0.7515, 2: 0.1374, 3: 0.3184, 5: 0.3823, 8: 1.0754, 9: 0.3344, 15: 0.5899, 21: 1.8551, 28: 1.1263, 31: 1.1113, 35: 3.3134, 36: 1.2545, 43: 2.3741, 45: 2.3753, 48: 1.2254, 51: 1.1879, 57: 11.0264, 61: 2.8957, 71: 2.1945, 78: 1.6947, 84: 6.5898, 86: 1.6136, 94: 2.3569, 97: 1.8218, 99: 2.6292, 100: 1.9206, 115: 2.3592, 147: 5.4841, 152: 2.1116, 169: 2.6328, 241: 2.5745, 283: 3.2325, 306: 3.2668, 350: 6.2367, 490: 3.8893, 578: 3.6182, 759: 3.7771, 832: 8.8964}), label=3.0)

# %%
df.filter(df.Id == '1112').show()
# Out:
# +--------------------+----+--------------------+--------------------+------+--------------------+----------+-------------+--------+--------------+--------------------+--------------------+--------------------+--------------------+-----+
# |                Body|  Id|                Tags|               Title|oneTag|               words|BodyLength|NumParagraphs|NumLinks|   NumFeatures|   ScaledNumFeatures|  ScaledNumFeatures2|                  TF|               TFIDF|label|
# +--------------------+----+--------------------+--------------------+------+--------------------+----------+-------------+--------+--------------+--------------------+--------------------+--------------------+--------------------+-----+
# |<p>I submitted my...|1112|iphone app-store ...|iPhone app releas...|iphone|[p, i, submitted,...|        63|            1|       0|[63.0,1.0,0.0]|[0.99987404748359...|[0.32825169441613...|(1000,[0,1,2,3,8,...|(1000,[0,1,2,3,8,...|  7.0|
# +--------------------+----+--------------------+--------------------+------+--------------------+----------+-------------+--------+--------------+--------------------+--------------------+--------------------+--------------------+-----+

# %%
df.persist()
# Out:
# DataFrame[Body: string, Id: bigint, Tags: string, Title: string, oneTag: string, words: array<string>, BodyLength: int, NumParagraphs: int, NumLinks: int, NumFeatures: vector, ScaledNumFeatures: vector, ScaledNumFeatures2: vector, TF: vector, TFIDF: vector, label: double]

# %%
df = df.withColumn('Joined_Body_Title', concat(col('Body'),lit(" "), col('Title')))

# %%
df.head()
# Out:
# Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'], BodyLength=83, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([83.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9997, 0.0241, 0.0]), ScaledNumFeatures2=DenseVector([0.4325, 0.7037, 0.0]), TF=SparseVector(1000, {0: 4.0, 1: 6.0, 2: 2.0, 3: 3.0, 5: 2.0, 8: 4.0, 9: 1.0, 15: 1.0, 21: 2.0, 28: 1.0, 31: 1.0, 35: 3.0, 36: 1.0, 43: 2.0, 45: 2.0, 48: 1.0, 51: 1.0, 57: 6.0, 61: 2.0, 71: 1.0, 78: 1.0, 84: 3.0, 86: 1.0, 94: 1.0, 97: 1.0, 99: 1.0, 100: 1.0, 115: 1.0, 147: 2.0, 152: 1.0, 169: 1.0, 241: 1.0, 283: 1.0, 306: 1.0, 350: 2.0, 490: 1.0, 578: 1.0, 759: 1.0, 832: 2.0}), TFIDF=SparseVector(1000, {0: 0.0026, 1: 0.7515, 2: 0.1374, 3: 0.3184, 5: 0.3823, 8: 1.0754, 9: 0.3344, 15: 0.5899, 21: 1.8551, 28: 1.1263, 31: 1.1113, 35: 3.3134, 36: 1.2545, 43: 2.3741, 45: 2.3753, 48: 1.2254, 51: 1.1879, 57: 11.0264, 61: 2.8957, 71: 2.1945, 78: 1.6947, 84: 6.5898, 86: 1.6136, 94: 2.3569, 97: 1.8218, 99: 2.6292, 100: 1.9206, 115: 2.3592, 147: 5.4841, 152: 2.1116, 169: 2.6328, 241: 2.5745, 283: 3.2325, 306: 3.2668, 350: 6.2367, 490: 3.8893, 578: 3.6182, 759: 3.7771, 832: 8.8964}), label=3.0, Joined_Body_Title="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n How to check if an uploaded file is an image without mime type?")

# %%
regexTokenizer = RegexTokenizer(inputCol='Joined_Body_Title', outputCol='Joined_Body_Title_words', pattern="\\W")
df = regexTokenizer.transform(df)
df.head()
# Out:
# Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'], BodyLength=83, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([83.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9997, 0.0241, 0.0]), ScaledNumFeatures2=DenseVector([0.4325, 0.7037, 0.0]), TF=SparseVector(1000, {0: 4.0, 1: 6.0, 2: 2.0, 3: 3.0, 5: 2.0, 8: 4.0, 9: 1.0, 15: 1.0, 21: 2.0, 28: 1.0, 31: 1.0, 35: 3.0, 36: 1.0, 43: 2.0, 45: 2.0, 48: 1.0, 51: 1.0, 57: 6.0, 61: 2.0, 71: 1.0, 78: 1.0, 84: 3.0, 86: 1.0, 94: 1.0, 97: 1.0, 99: 1.0, 100: 1.0, 115: 1.0, 147: 2.0, 152: 1.0, 169: 1.0, 241: 1.0, 283: 1.0, 306: 1.0, 350: 2.0, 490: 1.0, 578: 1.0, 759: 1.0, 832: 2.0}), TFIDF=SparseVector(1000, {0: 0.0026, 1: 0.7515, 2: 0.1374, 3: 0.3184, 5: 0.3823, 8: 1.0754, 9: 0.3344, 15: 0.5899, 21: 1.8551, 28: 1.1263, 31: 1.1113, 35: 3.3134, 36: 1.2545, 43: 2.3741, 45: 2.3753, 48: 1.2254, 51: 1.1879, 57: 11.0264, 61: 2.8957, 71: 2.1945, 78: 1.6947, 84: 6.5898, 86: 1.6136, 94: 2.3569, 97: 1.8218, 99: 2.6292, 100: 1.9206, 115: 2.3592, 147: 5.4841, 152: 2.1116, 169: 2.6328, 241: 2.5745, 283: 3.2325, 306: 3.2668, 350: 6.2367, 490: 3.8893, 578: 3.6182, 759: 3.7771, 832: 8.8964}), label=3.0, Joined_Body_Title="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n How to check if an uploaded file is an image without mime type?", Joined_Body_Title_words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p', 'how', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'without', 'mime', 'type'])

# %%
body_length = udf(lambda x: len(x), IntegerType())
df = df.withColumn('Length_Body_Title', body_length('Joined_Body_Title_words'))

# %%
df.head()
# Out:
# Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'], BodyLength=83, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([83.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9997, 0.0241, 0.0]), ScaledNumFeatures2=DenseVector([0.4325, 0.7037, 0.0]), TF=SparseVector(1000, {0: 4.0, 1: 6.0, 2: 2.0, 3: 3.0, 5: 2.0, 8: 4.0, 9: 1.0, 15: 1.0, 21: 2.0, 28: 1.0, 31: 1.0, 35: 3.0, 36: 1.0, 43: 2.0, 45: 2.0, 48: 1.0, 51: 1.0, 57: 6.0, 61: 2.0, 71: 1.0, 78: 1.0, 84: 3.0, 86: 1.0, 94: 1.0, 97: 1.0, 99: 1.0, 100: 1.0, 115: 1.0, 147: 2.0, 152: 1.0, 169: 1.0, 241: 1.0, 283: 1.0, 306: 1.0, 350: 2.0, 490: 1.0, 578: 1.0, 759: 1.0, 832: 2.0}), TFIDF=SparseVector(1000, {0: 0.0026, 1: 0.7515, 2: 0.1374, 3: 0.3184, 5: 0.3823, 8: 1.0754, 9: 0.3344, 15: 0.5899, 21: 1.8551, 28: 1.1263, 31: 1.1113, 35: 3.3134, 36: 1.2545, 43: 2.3741, 45: 2.3753, 48: 1.2254, 51: 1.1879, 57: 11.0264, 61: 2.8957, 71: 2.1945, 78: 1.6947, 84: 6.5898, 86: 1.6136, 94: 2.3569, 97: 1.8218, 99: 2.6292, 100: 1.9206, 115: 2.3592, 147: 5.4841, 152: 2.1116, 169: 2.6328, 241: 2.5745, 283: 3.2325, 306: 3.2668, 350: 6.2367, 490: 3.8893, 578: 3.6182, 759: 3.7771, 832: 8.8964}), label=3.0, Joined_Body_Title="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n How to check if an uploaded file is an image without mime type?", Joined_Body_Title_words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p', 'how', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'without', 'mime', 'type'], Length_Body_Title=96)

# %%
df.filter(df.Id == '5123').show()
# Out:
# +--------------------+----+----------+--------------------+------+--------------------+----------+-------------+--------+---------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+-----------------------+-----------------+
# |                Body|  Id|      Tags|               Title|oneTag|               words|BodyLength|NumParagraphs|NumLinks|    NumFeatures|   ScaledNumFeatures|  ScaledNumFeatures2|                  TF|               TFIDF|label|   Joined_Body_Title|Joined_Body_Title_words|Length_Body_Title|
# +--------------------+----+----------+--------------------+------+--------------------+----------+-------------+--------+---------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+-----------------------+-----------------+
# |<p>Here's an inte...|5123|git branch|Git branch experi...|   git|[p, here, s, an, ...|       132|            3|       0|[132.0,3.0,0.0]|[0.99974183554494...|[0.68776545496714...|(1000,[0,1,2,3,4,...|(1000,[0,1,2,3,4,...| 30.0|<p>Here's an inte...|   [p, here, s, an, ...|              135|
# +--------------------+----+----------+--------------------+------+--------------------+----------+-------------+--------+---------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+-----------------------+-----------------+

# %%
assembler1 = VectorAssembler(inputCols = ['Length_Body_Title'], outputCol = "NumFeatures_Body_Title")
df = assembler1.transform(df)

# %%
df.head()
# Out:
# Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'], BodyLength=83, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([83.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9997, 0.0241, 0.0]), ScaledNumFeatures2=DenseVector([0.4325, 0.7037, 0.0]), TF=SparseVector(1000, {0: 4.0, 1: 6.0, 2: 2.0, 3: 3.0, 5: 2.0, 8: 4.0, 9: 1.0, 15: 1.0, 21: 2.0, 28: 1.0, 31: 1.0, 35: 3.0, 36: 1.0, 43: 2.0, 45: 2.0, 48: 1.0, 51: 1.0, 57: 6.0, 61: 2.0, 71: 1.0, 78: 1.0, 84: 3.0, 86: 1.0, 94: 1.0, 97: 1.0, 99: 1.0, 100: 1.0, 115: 1.0, 147: 2.0, 152: 1.0, 169: 1.0, 241: 1.0, 283: 1.0, 306: 1.0, 350: 2.0, 490: 1.0, 578: 1.0, 759: 1.0, 832: 2.0}), TFIDF=SparseVector(1000, {0: 0.0026, 1: 0.7515, 2: 0.1374, 3: 0.3184, 5: 0.3823, 8: 1.0754, 9: 0.3344, 15: 0.5899, 21: 1.8551, 28: 1.1263, 31: 1.1113, 35: 3.3134, 36: 1.2545, 43: 2.3741, 45: 2.3753, 48: 1.2254, 51: 1.1879, 57: 11.0264, 61: 2.8957, 71: 2.1945, 78: 1.6947, 84: 6.5898, 86: 1.6136, 94: 2.3569, 97: 1.8218, 99: 2.6292, 100: 1.9206, 115: 2.3592, 147: 5.4841, 152: 2.1116, 169: 2.6328, 241: 2.5745, 283: 3.2325, 306: 3.2668, 350: 6.2367, 490: 3.8893, 578: 3.6182, 759: 3.7771, 832: 8.8964}), label=3.0, Joined_Body_Title="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n How to check if an uploaded file is an image without mime type?", Joined_Body_Title_words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p', 'how', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'without', 'mime', 'type'], Length_Body_Title=96, NumFeatures_Body_Title=DenseVector([96.0]))

# %%
scaler3 = Normalizer(inputCol = 'NumFeatures_Body_Title', outputCol ='ScaledNumFeatures_Body_Title' )
df = scaler3.transform(df)

# %%
df.head(2)
# Out:
# [Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'], BodyLength=83, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([83.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9997, 0.0241, 0.0]), ScaledNumFeatures2=DenseVector([0.4325, 0.7037, 0.0]), TF=SparseVector(1000, {0: 4.0, 1: 6.0, 2: 2.0, 3: 3.0, 5: 2.0, 8: 4.0, 9: 1.0, 15: 1.0, 21: 2.0, 28: 1.0, 31: 1.0, 35: 3.0, 36: 1.0, 43: 2.0, 45: 2.0, 48: 1.0, 51: 1.0, 57: 6.0, 61: 2.0, 71: 1.0, 78: 1.0, 84: 3.0, 86: 1.0, 94: 1.0, 97: 1.0, 99: 1.0, 100: 1.0, 115: 1.0, 147: 2.0, 152: 1.0, 169: 1.0, 241: 1.0, 283: 1.0, 306: 1.0, 350: 2.0, 490: 1.0, 578: 1.0, 759: 1.0, 832: 2.0}), TFIDF=SparseVector(1000, {0: 0.0026, 1: 0.7515, 2: 0.1374, 3: 0.3184, 5: 0.3823, 8: 1.0754, 9: 0.3344, 15: 0.5899, 21: 1.8551, 28: 1.1263, 31: 1.1113, 35: 3.3134, 36: 1.2545, 43: 2.3741, 45: 2.3753, 48: 1.2254, 51: 1.1879, 57: 11.0264, 61: 2.8957, 71: 2.1945, 78: 1.6947, 84: 6.5898, 86: 1.6136, 94: 2.3569, 97: 1.8218, 99: 2.6292, 100: 1.9206, 115: 2.3592, 147: 5.4841, 152: 2.1116, 169: 2.6328, 241: 2.5745, 283: 3.2325, 306: 3.2668, 350: 6.2367, 490: 3.8893, 578: 3.6182, 759: 3.7771, 832: 8.8964}), label=3.0, Joined_Body_Title="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n How to check if an uploaded file is an image without mime type?", Joined_Body_Title_words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p', 'how', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'without', 'mime', 'type'], Length_Body_Title=96, NumFeatures_Body_Title=DenseVector([96.0]), ScaledNumFeatures_Body_Title=DenseVector([1.0])),
#  Row(Body='<p>In my favorite editor (vim), I regularly use ctrl-w to execute a certain action. Now, it quite often happens to me that firefox is the active window (on windows) while I still look at vim (thinking vim is the active window) and press ctrl-w which closes firefox. This is not what I want. Is there a way to stop ctrl-w from closing firefox?</p>\n\n<p>Rene</p>\n', Id=2, Tags='firefox', Title='How can I prevent firefox from closing when I press ctrl-w', oneTag='firefox', words=['p', 'in', 'my', 'favorite', 'editor', 'vim', 'i', 'regularly', 'use', 'ctrl', 'w', 'to', 'execute', 'a', 'certain', 'action', 'now', 'it', 'quite', 'often', 'happens', 'to', 'me', 'that', 'firefox', 'is', 'the', 'active', 'window', 'on', 'windows', 'while', 'i', 'still', 'look', 'at', 'vim', 'thinking', 'vim', 'is', 'the', 'active', 'window', 'and', 'press', 'ctrl', 'w', 'which', 'closes', 'firefox', 'this', 'is', 'not', 'what', 'i', 'want', 'is', 'there', 'a', 'way', 'to', 'stop', 'ctrl', 'w', 'from', 'closing', 'firefox', 'p', 'p', 'rene', 'p'], BodyLength=71, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([71.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9996, 0.0282, 0.0]), ScaledNumFeatures2=DenseVector([0.3699, 0.7037, 0.0]), TF=SparseVector(1000, {0: 4.0, 1: 2.0, 2: 3.0, 3: 3.0, 5: 2.0, 8: 4.0, 9: 1.0, 11: 1.0, 12: 1.0, 14: 1.0, 15: 1.0, 20: 1.0, 22: 1.0, 26: 1.0, 31: 1.0, 44: 1.0, 51: 1.0, 55: 1.0, 61: 1.0, 62: 1.0, 65: 1.0, 82: 1.0, 86: 1.0, 136: 1.0, 177: 1.0, 226: 1.0, 297: 1.0, 320: 2.0, 345: 1.0, 488: 1.0, 528: 3.0, 572: 1.0, 748: 1.0, 794: 1.0, 862: 1.0, 895: 1.0, 914: 2.0, 934: 3.0, 978: 1.0}), TFIDF=SparseVector(1000, {0: 0.0026, 1: 0.2505, 2: 0.2061, 3: 0.3184, 5: 0.3823, 8: 1.0754, 9: 0.3344, 11: 0.351, 12: 0.4688, 14: 0.4804, 15: 0.5899, 20: 0.8168, 22: 0.8387, 26: 0.9457, 31: 1.1113, 44: 1.7166, 51: 1.1879, 55: 1.2149, 61: 1.4478, 62: 1.3929, 65: 1.4652, 82: 1.577, 86: 1.6136, 136: 2.0009, 177: 2.6852, 226: 2.6154, 297: 2.7559, 320: 6.8359, 345: 3.4198, 488: 3.2856, 528: 12.7029, 572: 3.8099, 748: 4.0336, 794: 3.8411, 862: 3.915, 895: 3.9241, 914: 8.9135, 934: 12.8887, 978: 4.0179}), label=91.0, Joined_Body_Title='<p>In my favorite editor (vim), I regularly use ctrl-w to execute a certain action. Now, it quite often happens to me that firefox is the active window (on windows) while I still look at vim (thinking vim is the active window) and press ctrl-w which closes firefox. This is not what I want. Is there a way to stop ctrl-w from closing firefox?</p>\n\n<p>Rene</p>\n How can I prevent firefox from closing when I press ctrl-w', Joined_Body_Title_words=['p', 'in', 'my', 'favorite', 'editor', 'vim', 'i', 'regularly', 'use', 'ctrl', 'w', 'to', 'execute', 'a', 'certain', 'action', 'now', 'it', 'quite', 'often', 'happens', 'to', 'me', 'that', 'firefox', 'is', 'the', 'active', 'window', 'on', 'windows', 'while', 'i', 'still', 'look', 'at', 'vim', 'thinking', 'vim', 'is', 'the', 'active', 'window', 'and', 'press', 'ctrl', 'w', 'which', 'closes', 'firefox', 'this', 'is', 'not', 'what', 'i', 'want', 'is', 'there', 'a', 'way', 'to', 'stop', 'ctrl', 'w', 'from', 'closing', 'firefox', 'p', 'p', 'rene', 'p', 'how', 'can', 'i', 'prevent', 'firefox', 'from', 'closing', 'when', 'i', 'press', 'ctrl', 'w'], Length_Body_Title=83, NumFeatures_Body_Title=DenseVector([83.0]), ScaledNumFeatures_Body_Title=DenseVector([1.0]))]

# %%
df.filter(df.Id == '512').show()
# Out:
# +--------------------+---+--------------------+--------------------+------+--------------------+----------+-------------+--------+--------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+-----------------------+-----------------+----------------------+----------------------------+
# |                Body| Id|                Tags|               Title|oneTag|               words|BodyLength|NumParagraphs|NumLinks|   NumFeatures|   ScaledNumFeatures|  ScaledNumFeatures2|                  TF|               TFIDF|label|   Joined_Body_Title|Joined_Body_Title_words|Length_Body_Title|NumFeatures_Body_Title|ScaledNumFeatures_Body_Title|
# +--------------------+---+--------------------+--------------------+------+--------------------+----------+-------------+--------+--------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+-----------------------+-----------------+----------------------+----------------------------+
# |<p>I'd like to ha...|512|java optimization...|How can I see the...|  java|[p, i, d, like, t...|        46|            2|       0|[46.0,2.0,0.0]|[0.99905615835505...|[0.23967584036733...|(1000,[0,1,2,3,4,...|(1000,[0,1,2,3,4,...|  2.0|<p>I'd like to ha...|   [p, i, d, like, t...|               57|                [57.0]|                       [1.0]|
# +--------------------+---+--------------------+--------------------+------+--------------------+----------+-------------+--------+--------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+-----------------------+-----------------+----------------------+----------------------------+

# %%
scaler4 = StandardScaler(inputCol = 'NumFeatures_Body_Title', outputCol ='ScaledNumFeatures_Body_Title3', withStd = True, withMean = True)
scalerModel1 = scaler4.fit(df)
df = scalerModel1.transform(df)

# %%
df.head()
# Out:
# Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'], BodyLength=83, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([83.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9997, 0.0241, 0.0]), ScaledNumFeatures2=DenseVector([0.4325, 0.7037, 0.0]), TF=SparseVector(1000, {0: 4.0, 1: 6.0, 2: 2.0, 3: 3.0, 5: 2.0, 8: 4.0, 9: 1.0, 15: 1.0, 21: 2.0, 28: 1.0, 31: 1.0, 35: 3.0, 36: 1.0, 43: 2.0, 45: 2.0, 48: 1.0, 51: 1.0, 57: 6.0, 61: 2.0, 71: 1.0, 78: 1.0, 84: 3.0, 86: 1.0, 94: 1.0, 97: 1.0, 99: 1.0, 100: 1.0, 115: 1.0, 147: 2.0, 152: 1.0, 169: 1.0, 241: 1.0, 283: 1.0, 306: 1.0, 350: 2.0, 490: 1.0, 578: 1.0, 759: 1.0, 832: 2.0}), TFIDF=SparseVector(1000, {0: 0.0026, 1: 0.7515, 2: 0.1374, 3: 0.3184, 5: 0.3823, 8: 1.0754, 9: 0.3344, 15: 0.5899, 21: 1.8551, 28: 1.1263, 31: 1.1113, 35: 3.3134, 36: 1.2545, 43: 2.3741, 45: 2.3753, 48: 1.2254, 51: 1.1879, 57: 11.0264, 61: 2.8957, 71: 2.1945, 78: 1.6947, 84: 6.5898, 86: 1.6136, 94: 2.3569, 97: 1.8218, 99: 2.6292, 100: 1.9206, 115: 2.3592, 147: 5.4841, 152: 2.1116, 169: 2.6328, 241: 2.5745, 283: 3.2325, 306: 3.2668, 350: 6.2367, 490: 3.8893, 578: 3.6182, 759: 3.7771, 832: 8.8964}), label=3.0, Joined_Body_Title="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n How to check if an uploaded file is an image without mime type?", Joined_Body_Title_words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p', 'how', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'without', 'mime', 'type'], Length_Body_Title=96, NumFeatures_Body_Title=DenseVector([96.0]), ScaledNumFeatures_Body_Title=DenseVector([1.0]), ScaledNumFeatures_Body_Title3=DenseVector([-0.4387]))

# %% [markdown]
# df.filter(df.Id == '512').show()

# %%
minmaxscaler = MinMaxScaler(inputCol = 'NumFeatures_Body_Title', outputCol ='ScaledMinMax')
minmaxscaler_Model = minmaxscaler.fit(df)
df = minmaxscaler_Model.transform(df)

# %%
df.filter(df.Id == '512').show()
# Out:
# +--------------------+---+--------------------+--------------------+------+--------------------+----------+-------------+--------+--------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+-----------------------+-----------------+----------------------+----------------------------+-----------------------------+--------------------+
# |                Body| Id|                Tags|               Title|oneTag|               words|BodyLength|NumParagraphs|NumLinks|   NumFeatures|   ScaledNumFeatures|  ScaledNumFeatures2|                  TF|               TFIDF|label|   Joined_Body_Title|Joined_Body_Title_words|Length_Body_Title|NumFeatures_Body_Title|ScaledNumFeatures_Body_Title|ScaledNumFeatures_Body_Title3|        ScaledMinMax|
# +--------------------+---+--------------------+--------------------+------+--------------------+----------+-------------+--------+--------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+-----------------------+-----------------+----------------------+----------------------------+-----------------------------+--------------------+
# |<p>I'd like to ha...|512|java optimization...|How can I see the...|  java|[p, i, d, like, t...|        46|            2|       0|[46.0,2.0,0.0]|[0.99905615835505...|[0.23967584036733...|(1000,[0,1,2,3,4,...|(1000,[0,1,2,3,4,...|  2.0|<p>I'd like to ha...|   [p, i, d, like, t...|               57|                [57.0]|                       [1.0]|         [-0.6417314460998...|[0.00624833820792...|
# +--------------------+---+--------------------+--------------------+------+--------------------+----------+-------------+--------+--------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+-----------------------+-----------------+----------------------+----------------------------+-----------------------------+--------------------+

# %%
pca = PCA(k = 100, inputCol = 'TFIDF', outputCol = 'pcaTFIDF')
model = pca.fit(df)
df = model.transform(df)

# %%
df.head()
# Out:
# Row(Body="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n", Id=1, Tags='php image-processing file-upload upload mime-types', Title='How to check if an uploaded file is an image without mime type?', oneTag='php', words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p'], BodyLength=83, NumParagraphs=2, NumLinks=0, NumFeatures=DenseVector([83.0, 2.0, 0.0]), ScaledNumFeatures=DenseVector([0.9997, 0.0241, 0.0]), ScaledNumFeatures2=DenseVector([0.4325, 0.7037, 0.0]), TF=SparseVector(1000, {0: 4.0, 1: 6.0, 2: 2.0, 3: 3.0, 5: 2.0, 8: 4.0, 9: 1.0, 15: 1.0, 21: 2.0, 28: 1.0, 31: 1.0, 35: 3.0, 36: 1.0, 43: 2.0, 45: 2.0, 48: 1.0, 51: 1.0, 57: 6.0, 61: 2.0, 71: 1.0, 78: 1.0, 84: 3.0, 86: 1.0, 94: 1.0, 97: 1.0, 99: 1.0, 100: 1.0, 115: 1.0, 147: 2.0, 152: 1.0, 169: 1.0, 241: 1.0, 283: 1.0, 306: 1.0, 350: 2.0, 490: 1.0, 578: 1.0, 759: 1.0, 832: 2.0}), TFIDF=SparseVector(1000, {0: 0.0026, 1: 0.7515, 2: 0.1374, 3: 0.3184, 5: 0.3823, 8: 1.0754, 9: 0.3344, 15: 0.5899, 21: 1.8551, 28: 1.1263, 31: 1.1113, 35: 3.3134, 36: 1.2545, 43: 2.3741, 45: 2.3753, 48: 1.2254, 51: 1.1879, 57: 11.0264, 61: 2.8957, 71: 2.1945, 78: 1.6947, 84: 6.5898, 86: 1.6136, 94: 2.3569, 97: 1.8218, 99: 2.6292, 100: 1.9206, 115: 2.3592, 147: 5.4841, 152: 2.1116, 169: 2.6328, 241: 2.5745, 283: 3.2325, 306: 3.2668, 350: 6.2367, 490: 3.8893, 578: 3.6182, 759: 3.7771, 832: 8.8964}), label=3.0, Joined_Body_Title="<p>I'd like to check if an uploaded file is an image file (e.g png, jpg, jpeg, gif, bmp) or another file. The problem is that I'm using Uploadify to upload the files, which changes the mime type and gives a 'text/octal' or something as the mime type, no matter which file type you upload.</p>\n\n<p>Is there a way to check if the uploaded file is an image apart from checking the file extension using PHP?</p>\n How to check if an uploaded file is an image without mime type?", Joined_Body_Title_words=['p', 'i', 'd', 'like', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'file', 'e', 'g', 'png', 'jpg', 'jpeg', 'gif', 'bmp', 'or', 'another', 'file', 'the', 'problem', 'is', 'that', 'i', 'm', 'using', 'uploadify', 'to', 'upload', 'the', 'files', 'which', 'changes', 'the', 'mime', 'type', 'and', 'gives', 'a', 'text', 'octal', 'or', 'something', 'as', 'the', 'mime', 'type', 'no', 'matter', 'which', 'file', 'type', 'you', 'upload', 'p', 'p', 'is', 'there', 'a', 'way', 'to', 'check', 'if', 'the', 'uploaded', 'file', 'is', 'an', 'image', 'apart', 'from', 'checking', 'the', 'file', 'extension', 'using', 'php', 'p', 'how', 'to', 'check', 'if', 'an', 'uploaded', 'file', 'is', 'an', 'image', 'without', 'mime', 'type'], Length_Body_Title=96, NumFeatures_Body_Title=DenseVector([96.0]), ScaledNumFeatures_Body_Title=DenseVector([1.0]), ScaledNumFeatures_Body_Title3=DenseVector([-0.4387]), ScaledMinMax=DenseVector([0.0114]), pcaTFIDF=DenseVector([-0.5291, -0.8217, 0.3129, 0.02, 0.0323, -0.1371, 0.1032, -0.1511, 0.4816, -0.2657, 0.9031, -0.1125, 3.1339, -0.4338, -0.1165, 0.3052, 0.9695, -0.7508, 0.1898, -1.0876, 0.5371, -0.8804, 1.5681, -0.37 ...
